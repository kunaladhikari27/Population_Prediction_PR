# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as pyp
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import classification_report,confusion_matrix

# %%
ds=pd.read_csv("population.csv")
x=ds.iloc[:,0:1].values
y=ds.iloc[:,1].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
reg=LinearRegression()
reg.fit(x_train,y_train)
print(reg.score(x_test,y_test))
# Out:
# 0.7743928690413535

# %%
pyp.scatter(x_train,y_train,color='red')
pyp.plot(x_train,reg.predict(x_train),color='blue')
pyp.title("Population vs year graph")
pyp.xlabel("Year")
pyp.ylabel("Population")
pyp.show()

# %%
 pyp.scatter(x_test,y_test,color='red')
pyp.plot(x_test,reg.predict(x_test),color='blue')
pyp.title("Testing graph")
pyp.xlabel("Year")
pyp.ylabel("Population")
pyp.show()

# %%
poly_reg=PolynomialFeatures(degree=3)
plt.scatter(x_test,y_test,color='red')
plt.show() 
ro_2=LinearRegression()
x_poly=poly_reg.fit_transform(x_train)
ro_2.fit(x_poly,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
x_poly_pred=poly_reg.fit_transform(2021)
y_pred=ro_2.predict(x_poly_pred)
print(int(y_pred))
# Out:
# 1465571160
